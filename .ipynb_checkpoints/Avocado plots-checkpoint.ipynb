# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# %%
df = pd.read_csv('avocado.csv', parse_dates=['Date'])
df.drop('Unnamed: 0', axis=1, inplace=True)
df = df.sort_values(by=['Date', 'type'])
df.head()
# Out:
#           Date  AveragePrice  Total Volume       4046       4225      4770  \
# 51  2015-01-04          1.22      40873.28    2819.50   28287.42     49.90
# 103 2015-01-04          1.00     435021.49  364302.39   23821.16     82.15
# 155 2015-01-04          1.08     788025.06   53987.31  552906.04  39995.03
# 207 2015-01-04          1.01      80034.32   44562.12   24964.23   2752.35
# 259 2015-01-04          1.02     491738.00    7193.87  396752.18    128.82
#
#      Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 51      9716.46     9186.93      529.53          0.0  conventional  2015
# 103    46815.79    16707.15    30108.64          0.0  conventional  2015
# 155   141136.68   137146.07     3990.61          0.0  conventional  2015
# 207     7755.62     6064.30     1691.32          0.0  conventional  2015
# 259    87663.13    87406.84      256.29          0.0  conventional  2015
#
#                   region
# 51                Albany
# ...

# %%
total_volume = df.groupby(['year', 'region', 'type'])['Total Volume'].sum()
total_volume = total_volume.reset_index()
total_volume.groupby(['year','type']).sum().reset_index()
# Out:
#    year          type  Total Volume
# 0  2015  conventional  4.296599e+09
# 1  2015       organic  8.886943e+07
# 2  2016  conventional  4.690250e+09
# 3  2016       organic  1.306401e+08
# 4  2017  conventional  4.766166e+09
# 5  2017       organic  1.681399e+08
# 6  2018  conventional  1.334206e+09
# 7  2018       organic  4.853227e+07

# %%
fig = px.line(albany, albany.index, 'AveragePrice', color='type')
fig.update_layout(
    font = dict(family='Arial', size=12),
    xaxis = dict(title = 'Date'))
fig.show()
# Out:
# <div>
#
#
#             <div id="f043913a-fbc3-430e-8aae-8ac19c652fb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f043913a-fbc3-430e-8aae-8ac19c652fb9")) {
#                     Plotly.newPlot(
#                         'f043913a-fbc3-430e-8aae-8ac19c652fb9',
# ...

# %%
fig = px.bar(total_volume, x='year', y='Total Volume', color='type', barmode='group', labels={'year':'Year'})
fig.show()
# Out:
# <div>
#
#
#             <div id="a03f906e-f4b8-4155-a23b-6f79a4657087" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a03f906e-f4b8-4155-a23b-6f79a4657087")) {
#                     Plotly.newPlot(
#                         'a03f906e-f4b8-4155-a23b-6f79a4657087',
# ...
